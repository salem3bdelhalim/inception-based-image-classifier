# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import os
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import *
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import numpy as np
from keras.callbacks import EarlyStopping,ReduceLROnPlateau
from keras.initializers import he_normal

# %%
data_path = '/kaggle/input/datasets/hasibalmuzdadid/shoe-vs-sandal-vs-boot-dataset-15k-images/Shoe vs Sandal vs Boot Dataset'

# %%
images_class = os.listdir('/kaggle/input/datasets/hasibalmuzdadid/shoe-vs-sandal-vs-boot-dataset-15k-images/Shoe vs Sandal vs Boot Dataset')
images_class
# Out:
# ['Shoe', 'Sandal', 'Boot']

# %%
def plot_images(images_class):
    plt.figure(figsize=(14, 6))
    
    for i, category in enumerate(images_class):
        image_path = os.path.join(data_path, category)
        images_in_folder = os.listdir(image_path)
        
        if len(images_in_folder) == 0:
            continue
        
        first_image = images_in_folder[0]
        first_image_path = os.path.join(image_path, first_image)
        
        img = image.load_img(first_image_path, target_size=(224, 224))
        img_array = image.img_to_array(img) / 255.0
        
        plt.subplot(1, len(images_class), i + 1)
        plt.imshow(img_array)
        plt.title(category)
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()


plot_images(images_class)

# %%
base_dir = '/kaggle/working/shoe-vs-sandal-vs-boot'
os.makedirs(base_dir, exist_ok=True)
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

for d in [train_dir, val_dir, test_dir]:
    os.makedirs(d, exist_ok=True)

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

for category in images_class:
    src_folder = os.path.join(data_path, category)
    images = os.listdir(src_folder)

    # 80% train, 20% temp
    train_imgs, temp_imgs = train_test_split(
        images, test_size=0.2, random_state=42
    )

    # 10% val, 10% test
    val_imgs, test_imgs = train_test_split(
        temp_imgs, test_size=0.5, random_state=42
    )

    for folder, img_list in zip(
        [train_dir, val_dir, test_dir],
        [train_imgs, val_imgs, test_imgs]
    ):
        dest = os.path.join(folder, category)
        os.makedirs(dest, exist_ok=True)

        for img_name in img_list:
            shutil.copy(
                os.path.join(src_folder, img_name),
                os.path.join(dest, img_name)
            )

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.25, 
    height_shift_range=0.25,
    shear_range=0.3,
    zoom_range=0.35,
    horizontal_flip=True
)

# %%
val_test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(120,120),
    batch_size=32,
    class_mode='categorical',
    shuffle=True,
    seed=42
)
# Out:
# Found 12000 images belonging to 3 classes.

# %%
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(120,120),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 1500 images belonging to 3 classes.

# %%
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(120,120),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 1500 images belonging to 3 classes.

# %% [markdown]
# # inception wirh factorization

# %%
def inception_module_factorized(x, filters):
    f1, f3, f5, f_pool = filters

    # 1x1
    conv1 = Conv2D(f1, (1,1), padding='same', activation='relu')(x)

    # Replace a 3x3 convolution with two factorized convolutions (1x3 followed by 3x1)
    conv3 = Conv2D(f3, (1,1), padding='same', activation='relu')(x)
    conv3 = Conv2D(f3, (1,3), padding='same', activation='relu')(conv3)
    conv3 = Conv2D(f3, (3,1), padding='same', activation='relu')(conv3)

    # Replace a 5x5 convolution with two factorized convolutions (3x3 + 3x3) 
    conv5 = Conv2D(f5, (1,1), padding='same', activation='relu')(x)
    conv5 = Conv2D(f5, (1,3), padding='same', activation='relu')(conv5)
    conv5 = Conv2D(f5, (3,1), padding='same', activation='relu')(conv5)
    conv5 = Conv2D(f5, (1,3), padding='same', activation='relu')(conv5)
    conv5 = Conv2D(f5, (3,1), padding='same', activation='relu')(conv5)

    # pooling branch
    pool = MaxPooling2D((3,3), strides=(1,1), padding='same')(x)
    pool = Conv2D(f_pool, (1,1), padding='same', activation='relu')(pool)

    # concat
    output = Concatenate()([conv1, conv3, conv5, pool])

    return output

# %%
from keras.models import Model
inputs = Input(shape=(120,120,3))

x = Conv2D(32, (3,3), padding='same', activation='relu')(inputs)
x = MaxPooling2D()(x)

# Inception Block 1
x = inception_module_factorized(x, [32, 32, 32, 32])
x = MaxPooling2D()(x)

# Inception Block 2
x = inception_module_factorized(x, [64, 64, 64, 64])
x = MaxPooling2D()(x)

# Inception Block 3
x = inception_module_factorized(x, [128, 128, 128, 128])
x = MaxPooling2D()(x)


x = Flatten()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0
0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_27    │ (None, 7, 7, 512) │          0 │ concatenate_11[0… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_3 (Flatten) │ (None, 25088)     │          0 │ max_pooling2d_27… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 256)       │  6,422,784 │ flatten_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 256)       │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 3)         │        771 │ dropout_3[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 6,981,699 (26.63 MB)
#  Trainable params: 6,981,699 (26.63 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'])

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

# %%
reduce_lr =ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=2,
    min_lr=1e-6
)

# %%
model_history = model.fit(
    train_generator,
    epochs=40,
    validation_data=val_generator,
    callbacks=[early_stop, reduce_lr]
)
# Out:
# Epoch 1/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 66s 137ms/step - accuracy: 0.5085 - loss: 0.9906 - val_accuracy: 0.7793 - val_loss: 0.5028 - learning_rate: 0.0010
# Epoch 2/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 129ms/step - accuracy: 0.7267 - loss: 0.6403 - val_accuracy: 0.8160 - val_loss: 0.4409 - learning_rate: 0.0010
# Epoch 3/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 49s 129ms/step - accuracy: 0.7749 - loss: 0.5462 - val_accuracy: 0.8740 - val_loss: 0.2954 - learning_rate: 0.0010
# Epoch 4/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 129ms/step - accuracy: 0.8152 - loss: 0.4543 - val_accuracy: 0.8813 - val_loss: 0.2702 - learning_rate: 0.0010
# Epoch 5/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 129ms/step - accuracy: 0.8489 - loss: 0.3720 - val_accuracy: 0.9327 - val_loss: 0.1674 - learning_rate: 0.0010
# Epoch 6/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 128ms/step - accuracy: 0.8701 - loss: 0.3359 - val_accuracy: 0.9140 - val_loss: 0.2171 - learning_rate: 0.0010
# Epoch 7/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 49s 130ms/step - accuracy: 0.8812 - loss: 0.3037 - val_accuracy: 0.9487 - val_loss: 0.1348 - learning_rate: 0.0010
# Epoch 8/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 129ms/step - accuracy: 0.8803 - loss: 0.3048 - val_accuracy: 0.9340 - val_loss: 0.1628 - learning_rate: 0.0010
# Epoch 9/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 128ms/step - accuracy: 0.8948 - loss: 0.2691 - val_accuracy: 0.9547 - val_loss: 0.1261 - learning_rate: 0.0010
# Epoch 10/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 49s 130ms/step - accuracy: 0.9071 - loss: 0.2503 - val_accuracy: 0.9607 - val_loss: 0.1027 - learning_rate: 0.0010
# Epoch 11/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 50s 132ms/step - accuracy: 0.9039 - loss: 0.2517 - val_accuracy: 0.9453 - val_loss: 0.1342 - learning_rate: 0.0010
# Epoch 12/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 49s 131ms/step - accuracy: 0.9145 - loss: 0.2384 - val_accuracy: 0.9513 - val_loss: 0.1226 - learning_rate: 0.0010
# Epoch 13/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 50s 132ms/step - accuracy: 0.9314 - loss: 0.1797 - val_accuracy: 0.9720 - val_loss: 0.0808 - learning_rate: 3.0000e-04
# Epoch 14/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 50s 133ms/step - accuracy: 0.9411 - loss: 0.1655 - val_accuracy: 0.9747 - val_loss: 0.0758 - learning_rate: 3.0000e-04
# Epoch 15/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 49s 130ms/step - accuracy: 0.9363 - loss: 0.1713 - val_accuracy: 0.9733 - val_loss: 0.0739 - learning_rate: 3.0000e-04
# Epoch 16/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 128ms/step - accuracy: 0.9446 - loss: 0.1501 - val_accuracy: 0.9713 - val_loss: 0.0912 - learning_rate: 3.0000e-04
# Epoch 17/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 129ms/step - accuracy: 0.9472 - loss: 0.1491 - val_accuracy: 0.9760 - val_loss: 0.0728 - learning_rate: 3.0000e-04
# Epoch 18/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 128ms/step - accuracy: 0.9402 - loss: 0.1584 - val_accuracy: 0.9767 - val_loss: 0.0726 - learning_rate: 3.0000e-04
# Epoch 19/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 49s 130ms/step - accuracy: 0.9498 - loss: 0.1371 - val_accuracy: 0.9740 - val_loss: 0.0741 - learning_rate: 3.0000e-04
# Epoch 20/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 49s 129ms/step - accuracy: 0.9471 - loss: 0.1399 - val_accuracy: 0.9740 - val_loss: 0.0702 - learning_rate: 3.0000e-04
# Epoch 21/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 129ms/step - accuracy: 0.9494 - loss: 0.1365 - val_accuracy: 0.9787 - val_loss: 0.0648 - learning_rate: 3.0000e-04
# Epoch 22/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 129ms/step - accuracy: 0.9524 - loss: 0.1368 - val_accuracy: 0.9787 - val_loss: 0.0720 - learning_rate: 3.0000e-04
# Epoch 23/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 129ms/step - accuracy: 0.9482 - loss: 0.1394 - val_accuracy: 0.9700 - val_loss: 0.0813 - learning_rate: 3.0000e-04
# Epoch 24/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 129ms/step - accuracy: 0.9514 - loss: 0.1384 - val_accuracy: 0.9800 - val_loss: 0.0638 - learning_rate: 9.0000e-05
# Epoch 25/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 49s 130ms/step - accuracy: 0.9585 - loss: 0.1130 - val_accuracy: 0.9793 - val_loss: 0.0709 - learning_rate: 9.0000e-05
# Epoch 26/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 129ms/step - accuracy: 0.9580 - loss: 0.1171 - val_accuracy: 0.9780 - val_loss: 0.0684 - learning_rate: 9.0000e-05
# Epoch 27/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 49s 130ms/step - accuracy: 0.9616 - loss: 0.1022 - val_accuracy: 0.9820 - val_loss: 0.0597 - learning_rate: 2.7000e-05
# Epoch 28/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 129ms/step - accuracy: 0.9644 - loss: 0.0995 - val_accuracy: 0.9820 - val_loss: 0.0587 - learning_rate: 2.7000e-05
# Epoch 29/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 129ms/step - accuracy: 0.9617 - loss: 0.1072 - val_accuracy: 0.9840 - val_loss: 0.0572 - learning_rate: 2.7000e-05
# Epoch 30/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 128ms/step - accuracy: 0.9596 - loss: 0.1073 - val_accuracy: 0.9840 - val_loss: 0.0585 - learning_rate: 2.7000e-05
# Epoch 31/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 129ms/step - accuracy: 0.9628 - loss: 0.1053 - val_accuracy: 0.9827 - val_loss: 0.0567 - learning_rate: 2.7000e-05
# Epoch 32/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 127ms/step - accuracy: 0.9623 - loss: 0.1081 - val_accuracy: 0.9847 - val_loss: 0.0575 - learning_rate: 2.7000e-05
# Epoch 33/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 128ms/step - accuracy: 0.9589 - loss: 0.1102 - val_accuracy: 0.9813 - val_loss: 0.0555 - learning_rate: 2.7000e-05
# Epoch 34/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 128ms/step - accuracy: 0.9621 - loss: 0.1035 - val_accuracy: 0.9827 - val_loss: 0.0552 - learning_rate: 2.7000e-05
# Epoch 35/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 129ms/step - accuracy: 0.9643 - loss: 0.1037 - val_accuracy: 0.9847 - val_loss: 0.0549 - learning_rate: 2.7000e-05
# Epoch 36/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 128ms/step - accuracy: 0.9594 - loss: 0.1060 - val_accuracy: 0.9840 - val_loss: 0.0542 - learning_rate: 2.7000e-05
# Epoch 37/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 128ms/step - accuracy: 0.9633 - loss: 0.1013 - val_accuracy: 0.9820 - val_loss: 0.0559 - learning_rate: 2.7000e-05
# Epoch 38/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 129ms/step - accuracy: 0.9628 - loss: 0.1011 - val_accuracy: 0.9827 - val_loss: 0.0539 - learning_rate: 2.7000e-05
# Epoch 39/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 128ms/step - accuracy: 0.9629 - loss: 0.1019 - val_accuracy: 0.9840 - val_loss: 0.0586 - learning_rate: 2.7000e-05
# Epoch 40/40
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 128ms/step - accuracy: 0.9624 - loss: 0.1037 - val_accuracy: 0.9847 - val_loss: 0.0563 - learning_rate: 2.7000e-05

# %%
plt.plot(model_history.history['loss'], label = 'Train Loss')
plt.plot(model_history.history['val_loss'], label = 'Validation Loss')
plt.legend() 
plt.show()

# %%
model.evaluate(test_generator)
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9890 - loss: 0.0387
# [0.06299052387475967, 0.9819999933242798]

# %%
test_generator.reset()  
pred = model.predict(test_generator, verbose=1)
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step

# %%
y_pred = np.argmax(pred, axis=1)
y_true = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# %%
acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, average='weighted', zero_division=0)
rec = recall_score(y_true, y_pred, average='weighted', zero_division=0)
f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

# %%
print(f"Accuracy:  {acc:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall:    {rec:.4f}")
print(f"F1 Score:  {f1:.4f}")
# Out:
# Accuracy:  0.9820
# Precision: 0.9820
# Recall:    0.9820
# F1 Score:  0.9820

# %%
cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[496   3   1]
#  [  4 486  10]
#  [  5   4 491]]

# %%
import seaborn as sns

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(7,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_labels, yticklabels=class_labels)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
